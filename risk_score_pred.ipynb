# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/leongrammy/Library/CloudStorage/GoogleDrive-leongramminger@gmail.com/My Drive/Private Work/dApp Micro Loans/credit_risk_dataset.csv')

# %%
df.shape
# Out:
# (32581, 12)

# %%
df.head(10)
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
# 5          21           9900                   OWN                2.0
# 6          26          77100                  RENT                8.0
# 7          24          78956                  RENT                5.0
# 8          24          83000                  RENT                8.0
# 9          21          10000                   OWN                6.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# ...

# %%
#drop columns with loan_grade, loan_percent_income, cb_person_default_on_file, cb_person_cred_hist_length
df = df.drop(['loan_grade', 'loan_percent_income', 'cb_person_default_on_file', 'cb_person_cred_hist_length'], axis=1)

# %%
df.head(10)
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
# 5          21           9900                   OWN                2.0
# 6          26          77100                  RENT                8.0
# 7          24          78956                  RENT                5.0
# 8          24          83000                  RENT                8.0
# 9          21          10000                   OWN                6.0
#
#   loan_intent  loan_amnt  loan_int_rate  loan_status
# 0    PERSONAL      35000          16.02            1
# 1   EDUCATION       1000          11.14            0
# ...

# %%
#remove missing values

df = df.dropna()

# %%
#show valuues of person_home_ownership
df['person_home_ownership'].value_counts()
# Out:
# person_home_ownership
# RENT        14551
# MORTGAGE    11801
# OWN          2192
# OTHER          94
# Name: count, dtype: int64
